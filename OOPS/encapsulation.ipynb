# %% [markdown]
# ### Encapsulation
# #### Encapsulation is the process of hiding the implementation of a class from the user. It is used in the case of sensitive data.

# %%
# Access Modifier
# 1.Public
# 2.Private
# 3.Protected

class Person:
  def __init__(self, name, age, gender, address, phone_no):
    self.name = name 
    self.age = age
    self.__gender = gender
    self.__address = address
    self.__phone_no = phone_no

  def get_info(self):
    print(f"Name: {self.name}")
    print(f"Age: {self.age}")
    print(f"Gender: {self.__gender}")
    print(f"Address: {self.__address}")
    print(f"Phone No: {self.__phone_no}")

  def set_info(self, name, age, gender, address, phone_no):
    self.name = name 
    self.age = age
    self.__gender = gender
    self.__address = address
    self.__phone_no = phone_no

Person1 = Person('Nilesh',22,'Male','Pune','1234567890')
Person1.get_info()
print(Person1.__address)  # AttributeError: 'Person' object has no attribute '_address'
# Out:
# Name: Nilesh
# Age: 22
# Gender: Male
# Address: Pune
# Phone No: 1234567890
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 30
#      28 Person1 = Person('Nilesh',22,'Male','Pune','1234567890')
#      29 Person1.get_info()
# ---> 30 print(Person1.__address)  # AttributeError: 'Person' object has no attribute '_address'
#
# AttributeError: 'Person' object has no attribute '__address'

# %%
print(Person1._address)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(Person1._address)
#
# AttributeError: 'Person' object has no attribute '_address'
