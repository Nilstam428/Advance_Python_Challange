# %%
import os
print(os.getcwd())
print(os.listdir())
print(sorted(os.listdir('../')))
# Out:
# /home/nilesh/Data/imp_data/GItHub Repo/Python-Practice/5-Modules
# ['5.1-import-moduls.ipynb', 'package', '5.2-standardLibraries.ipynb']
# ['.git', '.gitignore', '.venv', '1-Python-Basics', '2-Conrtol Flow', '3-Data Structures', '4-Functions', '5-Modules', 'Complete-Python-Bootcamp', 'Decorators', 'Generators', 'Mini_Bank_Project', 'OOPS', 'Pattern Printing', 'Practice Questions', 'iterators.ipynb', 'readme.md', 'requirements.txt', 'test.ipynb', 'test.py']

# %%
import shutil

shutil.copy('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
# Data serialization
import json
data = {
    'name': 'Nilesh',
    'age': 30,
    'city': 'Pune'}
json_string = json.dumps(data)
print(json_string)
print(type(json_string))
parsed_data = json.loads(json_string)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Nilesh", "age": 30, "city": "Pune"}
# <class 'str'>
# {'name': 'Nilesh', 'age': 30, 'city': 'Pune'}
# <class 'dict'>

# %%
# csv
import csv
with open('data.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'Age', 'City'])
    writer.writerow(['Nilesh', 30, 'Pune'])
    writer.writerow(['Alice', 25, 'New York'])
    writer.writerow(['Bob', 28, 'Los Angeles'])

# %%
with open('data.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age', 'City']
# ['Nilesh', '30', 'Pune']
# ['Alice', '25', 'New York']
# ['Bob', '28', 'Los Angeles']

# %%
# date_time
from datetime import datetime 
now = datetime.now()
print(now)
# Out:
# 2026-03-31 16:49:36.682969

# %%
from datetime import timedelta
yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2026-03-30 16:49:36.682969

# %%
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1774956051.357733
# 1774956053.3579857

# %%
import re
text = "This is a sample text with numbers 123 and symbols #!."
pattern = r'\d+'
matches = re.search(pattern, text)
print(matches.group())
# Out:
# 123
