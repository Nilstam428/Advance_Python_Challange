# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
math.pow(25,2)
# Out:
# 625.0

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
import numpy as np
arr = np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
from package import maths
print(maths.add(25,25))
print(maths.subtract(25,10))
# Out:
# 50
# 15

# %%
from package.maths import multiply, divide
print(multiply(25,25))
print(divide(25,5))
# Out:
# 625
# 5.0
